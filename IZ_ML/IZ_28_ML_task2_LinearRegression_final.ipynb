# %% [markdown]
# В прилагаемом файле представлены данные, собранные путем голосования за самые лучшие (или, по крайней мере, самые популярные) конфеты Хэллоуина. Обучите модель линейной многомерной регрессии. В качестве предикторов выступают поля: chocolate, fruity, caramel, peanutyalmondy, nougat, crispedricewafer, hard, bar, pluribus, sugarpercent, pricepercent, отклик — winpercent.
#
# В качестве тренировочного набора данных используйте данные из файла, за иключением следующих конфет: Chiclets, Fruit Chews. Обучите модель. Если используете Azure ML Studio, укажите random seed = 2019 в параметрах блока Linear Regression.
# Задача:
# 1.Введите предсказанное значение winpercent для конфеты Chiclets:
# 2.Введите предсказанное значение winpercent для конфеты Fruit Chews:
# 3.Введите предсказанное значение winpercent для конфеты с параметрами:

# %%
#чтение данных, так как названия конфет уникальны, используем их в качестве индекса
import pandas as pd
#подключаем модель линейной регрессии из библиотеки sklearn
from sklearn.linear_model import LinearRegression

df_cand = pd.read_csv("/Users/ekaterina/github_repos/ITMO_STUDY/ datasets/IZML_28_task2_candy-data.csv", delimiter=',', index_col='competitorname')

# %%
df_cand #.head(10)
# Out:
#                        chocolate  fruity  caramel  peanutyalmondy  nougat  \
# competitorname
# 100 Grand                      1       0        1               0       0
# 3 Musketeers                   1       0        0               0       1
# One dime                       0       0        0               0       0
# One quarter                    0       0        0               0       0
# Air Heads                      0       1        0               0       0
# ...                          ...     ...      ...             ...     ...
# Snickers Crisper               1       0        1               1       0
# Sour Patch Kids                0       1        0               0       0
# Sour Patch Tricksters          0       1        0               0       0
# Starburst                      0       1        0               0       0
# Strawberry bon bons            0       1        0               0       0
#
#                        crispedricewafer  hard  bar  pluribus  sugarpercent  \
# competitorname
# 100 Grand                             1     0    1         0         0.732
# 3 Musketeers                          0     0    1         0         0.604
# One dime                              0     0    0         0         0.011
# One quarter                           0     0    0         0         0.011
# Air Heads                             0     0    0         0         0.906
# ...                                 ...   ...  ...       ...           ...
# Snickers Crisper                      1     0    1         0         0.604
# Sour Patch Kids                       0     0    0         1         0.069
# Sour Patch Tricksters                 0     0    0         1         0.069
# Starburst                             0     0    0         1         0.151
# Strawberry bon bons                   0     1    0         1         0.569
#
#                        pricepercent  winpercent  Y
# competitorname
# 100 Grand                     0.860   66.971725  1
# 3 Musketeers                  0.511   67.602936  1
# One dime                      0.116   32.261086  0
# One quarter                   0.511   46.116505  0
# Air Heads                     0.511   52.341465  1
# ...                             ...         ... ..
# Snickers Crisper              0.651   59.529251  1
# Sour Patch Kids               0.116   59.863998  1
# Sour Patch Tricksters         0.116   52.825947  1
# Starburst                     0.220   67.037628  1
# Strawberry bon bons           0.058   34.578991  0
#
# [70 rows x 13 columns]

# %%
df_cand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 100 Grand to Strawberry bon bons
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chocolate         70 non-null     int64
#  1   fruity            70 non-null     int64
#  2   caramel           70 non-null     int64
#  3   peanutyalmondy    70 non-null     int64
#  4   nougat            70 non-null     int64
#  5   crispedricewafer  70 non-null     int64
#  6   hard              70 non-null     int64
#  7   bar               70 non-null     int64
#  8   pluribus          70 non-null     int64
#  9   sugarpercent      70 non-null     float64
#  10  pricepercent      70 non-null     float64
#  11  winpercent        70 non-null     float64
#  12  Y                 70 non-null     int64
# dtypes: float64(3), int64(10)
# memory usage: 7.7+ KB

# %%
#обучение модели будем проводить на данных, за исключением некоторых конфет
train_data = df_cand.drop(['Chiclets', 'Fruit Chews'])

# %%
train_data.head(20)
# Out:
#                             chocolate  fruity  caramel  peanutyalmondy  \
# competitorname
# 100 Grand                           1       0        1               0
# 3 Musketeers                        1       0        0               0
# One dime                            0       0        0               0
# One quarter                         0       0        0               0
# Air Heads                           0       1        0               0
# Almond Joy                          1       0        0               1
# Baby Ruth                           1       0        1               1
# Boston Baked Beans                  0       0        0               1
# Candy Corn                          0       0        0               0
# Caramel Apple Pops                  0       1        1               0
# Charleston Chew                     1       0        0               0
# Chewey Lemonhead Fruit Mix          0       1        0               0
# Dots                                0       1        0               0
# Dum Dums                            0       1        0               0
# Fun Dip                             0       1        0               0
# Gobstopper                          0       1        0               0
# Haribo Gold Bears                   0       1        0               0
# Haribo Happy Cola                   0       0        0               0
# Haribo Sour Bears                   0       1        0               0
# Haribo Twin Snakes                  0       1        0               0
#
#                             nougat  crispedricewafer  hard  bar  pluribus  \
# competitorname
# 100 Grand                        0                 1     0    1         0
# 3 Musketeers                     1                 0     0    1         0
# One dime                         0                 0     0    0         0
# One quarter                      0                 0     0    0         0
# Air Heads                        0                 0     0    0         0
# Almond Joy                       0                 0     0    1         0
# Baby Ruth                        1                 0     0    1         0
# Boston Baked Beans               0                 0     0    0         1
# Candy Corn                       0                 0     0    0         1
# Caramel Apple Pops               0                 0     0    0         0
# Charleston Chew                  1                 0     0    1         0
# Chewey Lemonhead Fruit Mix       0                 0     0    0         1
# Dots                             0                 0     0    0         1
# Dum Dums                         0                 0     1    0         0
# Fun Dip                          0                 0     1    0         0
# Gobstopper                       0                 0     1    0         1
# Haribo Gold Bears                0                 0     0    0         1
# Haribo Happy Cola                0                 0     0    0         1
# Haribo Sour Bears                0                 0     0    0         1
# Haribo Twin Snakes               0                 0     0    0         1
#
#                             sugarpercent  pricepercent  winpercent  Y
# competitorname
# 100 Grand                          0.732         0.860   66.971725  1
# 3 Musketeers                       0.604         0.511   67.602936  1
# One dime                           0.011         0.116   32.261086  0
# One quarter                        0.011         0.511   46.116505  0
# Air Heads                          0.906         0.511   52.341465  1
# Almond Joy                         0.465         0.767   50.347546  1
# Baby Ruth                          0.604         0.767   56.914547  1
# Boston Baked Beans                 0.313         0.511   23.417824  0
# Candy Corn                         0.906         0.325   38.010963  0
# Caramel Apple Pops                 0.604         0.325   34.517681  0
# Charleston Chew                    0.604         0.511   38.975037  0
# Chewey Lemonhead Fruit Mix         0.732         0.511   36.017628  0
# Dots                               0.732         0.511   42.272076  0
# Dum Dums                           0.732         0.034   39.460556  0
# Fun Dip                            0.732         0.325   39.185505  0
# Gobstopper                         0.906         0.453   46.783348  0
# Haribo Gold Bears                  0.465         0.465   57.119740  1
# Haribo Happy Cola                  0.465         0.465   34.158958  0
# Haribo Sour Bears                  0.465         0.465   51.412430  1
# Haribo Twin Snakes                 0.465         0.465   42.178772  0

# %%
#отбираем данные для предикторов, удаляя два последних столбца, индекс не включается в данные.
X = pd.DataFrame(train_data.drop(['winpercent', 'Y'], axis=1))

# %%
#указываем столбец отклика
y = pd.DataFrame(train_data['winpercent'])

# %%
#обучение модели
reg = LinearRegression().fit(X, y)

# %%
#предсказание для конфет введеных вручную
reg.predict([[0, 0, 1, 0, 1, 0, 1, 0, 1, 0.607, 0.254]])
# Out:
# array([[30.72196705]])

# %%
#предсказание для конфет из таблицы

#выбираем строку из таблицы
Chiclets = df_cand.loc['Chiclets',:].to_frame().T

#отбираем данные для предикторов и выполняем предсказание с помощью модели
reg.predict(Chiclets.drop(['winpercent', 'Y'], axis=1))
# Out:
# array([[42.86644948]])

# %%
#предсказание для конфет из таблицы

#выбираем строку из таблицы
FruitChews = df_cand.loc['Fruit Chews',:].to_frame().T

#отбираем данные для предикторов и выполняем предсказание с помощью модели
reg.predict(FruitChews.drop(['winpercent', 'Y'], axis=1))
# Out:
# array([[46.30862479]])

# %% [markdown]
# Значение коэффициента $\theta_0$:

# %%
reg.intercept_
# Out:
# array([36.65129553])

# %% [markdown]
# Значение коэффициентов $\theta_1, \ldots, \theta_p$:

# %%
reg.coef_
# Out:
# array([[25.77472951, 11.87480205, -1.82816139,  8.17152108,  3.76017256,
#         10.26127488, -8.2332688 , -4.98407556, -3.12430336,  9.59234636,
#         -9.15874697]])
